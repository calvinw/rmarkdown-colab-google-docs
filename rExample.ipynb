# %% [markdown]
# Here is some R:

# %%
x<-23
y<-12
z<-x+y
x
y
z

# %% [markdown]
#     ## [1] 23
#     ## [1] 12
#     ## [1] 35
#
# Some display math:
#
# $$
# x = \frac{2}{3}
# $$
#
# Some graphics

# %%
plot(runif(z))

# %% [markdown]
# ![](attachment:rExample_files/figure-markdown/unnamed-chunk-2-1.png)
